# %% [markdown]
# # Usage

# %% [markdown]
# ## list up available dictionaries

# %%
from mecab2pandas import MecabParser, listup_dictionaries

# %%
listup_dictionaries()
# Out:
# ['mecab-ipadic-neologd']

# %% [markdown]
# ## Using default dictionary

# %%
parser = MecabParser()

# %%
parser.parse("特急はくたか")
# Out:
#   surface_form word_class class_detail1 class_detail2 class_detail3  \
# 0           特急         名詞            一般          None          None
# 1            は         助詞           係助詞          None          None
# 2            く         動詞            自立          None          None
# 3            た        助動詞          None          None          None
# 4            か         助詞  副助詞／並立助詞／終助詞          None          None
#
#   conjugational_type conjugational_form original_form how_to_read  \
# 0               None               None            特急       トッキュウ
# 1               None               None             は           ハ
# 2              カ変・クル            体言接続特殊２            くる           ク
# 3               特殊・タ                基本形             た           タ
# 4               None               None             か           カ
#
#   pronunciation
# 0         トッキュー
# 1             ワ
# 2             ク
# 3             タ
# 4             カ

# %% [markdown]
# ## Using 'mecab-ipadic-neologd'

# %%
parser = MecabParser("mecab-ipadic-neologd")

# %%
parser.parse("特急はくたか")
# Out:
#   surface_form word_class class_detail1 class_detail2 class_detail3  \
# 0           特急         名詞            一般          None          None
# 1         はくたか         名詞          固有名詞            一般          None
#
#   conjugational_type conjugational_form original_form how_to_read  \
# 0               None               None            特急       トッキュウ
# 1               None               None          はくたか        ハクタカ
#
#   pronunciation
# 0         トッキュー
# 1          ハクタカ

# %%
parser.parse("命を大事に。ベホマを使え！")
# Out:
#   surface_form word_class class_detail1 class_detail2 class_detail3  \
# 0            命         名詞            一般          None          None
# 1            を         助詞           格助詞            一般          None
# 2           大事         名詞        形容動詞語幹          None          None
# 3            に         助詞           格助詞            一般          None
# 4            。         記号            句点          None          None
# 5          ベホマ         名詞          固有名詞            一般          None
# 6            を         助詞           格助詞            一般          None
# 7           使え         動詞            自立          None          None
# 8            ！         記号            一般          None          None
#
#   conjugational_type conjugational_form original_form how_to_read  \
# 0               None               None             命         イノチ
# 1               None               None             を           ヲ
# 2               None               None            大事         ダイジ
# 3               None               None             に           ニ
# 4               None               None             。           。
# 5               None               None           ベホマ         ベホマ
# 6               None               None             を           ヲ
# 7           五段・ワ行促音便                命令ｅ            使う         ツカエ
# 8               None               None             ！           ！
#
#   pronunciation
# 0           イノチ
# 1             ヲ
# 2           ダイジ
# 3             ニ
# 4             。
# 5           ベホマ
# 6             ヲ
# 7           ツカエ
# 8             ！
